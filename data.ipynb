# %%
import pandas as pd

# Read in CSV Weather Information
df = pd.read_csv('Resources/Weather_Data.csv')

# Save HTML File
df.to_html('data.html', index=False)

# Translate to String
table = df.to_html()
print(table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature (F)</th>
#       <th>Humidity (%)</th>
#       <th>Cloudiness (%)</th>
#       <th>Wind Speed (mph)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ilembula</td>
#       <td>-8.90</td>
#       <td>34.58</td>
#       <td>59.59</td>
#       <td>61</td>
#       <td>43</td>
#       <td>3.24</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Caledonia</td>
#       <td>42.81</td>
#       <td>-87.92</td>
#       <td>34.97</td>
#       <td>80</td>
#       <td>1</td>
#       <td>3.18</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lintangan</td>
#       <td>7.22</td>
#       <td>121.95</td>
#       <td>86.00</td>
#       <td>66</td>
#       <td>40</td>
#       <td>6.93</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...
